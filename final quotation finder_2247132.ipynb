# %% [markdown]
# 1.LAPTOP PURCHASE **quotation finder**

# %%
def gaming():  #defining function without parameter
   print("starting from 60k do you want to know  more say yes or no\n")
   decision=str(input("")) #giving input as string
   if decision=="yes": #using if conditional statement
     print("great!! let me tell you about the quotation of gaming laptops we have")
     print("basic version we have is 1.Acer nitro 5 =1tb ssd ,4gb graphics card,ryzen5,cost=59k\n") 
     print("2.acerpreadatrhelios=1tb ssd,1tb hdd ,4gb graphics card,ryzen5,cost=79k\n")
     print("3.acerpreadatrhelios300=1tb ssd,1tb hdd ,6gb graphics card,ryzen5,cost=1lac\n")
   else: #
     print("try for another one")
   print("enter the name of laptop")
   lapname=str(input(""))
   if lapname=="acer_nitro5":
     acer_nitro5=59000
     print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
     print("do you want to add some extra things say yes or no/yesn")
     extra=str(input(""))
     if extra=="yes" :
         print("ssd 1tb=10000,games=1000,softwares=900")
         extrapart=str(input())
         if extrapart=="ssd" :
           total_cost=acer_nitro5+10000
           print("Total:",total_cost)
         elif extrapart=="games" : #elif conditional statement is used
           total_cost=acer_nitro5+1000
           print("Total:",total_cost)
         elif extrapart=="softwares" :
           total_cost=acer_nitro5+900
           print("Total:",total_cost)
     else:
           print("try for another one")
           print("total cost",total_cost)

   elif lapname=="acerpreadatrhelios" :
       acer_preadatr_helios=79000
       print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
       print("do you want to add some extra things say yes or no\n")
       extra=str(input(""))
       if extra=="yes" :
           print("ssd 1tb=10000,games=1000,softwares=900")
           extrapart=str(input())
           if extrapart=="ssd" :
             total_cost=acer_preadatr_helios+10000
             print("Total:",total_cost)
           elif extrapart=="games" :
             total_cost=acer_preadatr_helios+1000
             print("Total:",total_cost)
           elif extrapart=="softwares" :
             total_cost=acer_preadatr_helios+900
             print("Total:",total_cost)
       else:
             print("try for another one")
             print("total cost",total_cost)
   elif lapname=="acerpreadatrhelios300" :
     acer_preadatr_helios300=100000
     print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
     print("do you want to add some extra things say yes or no\n")
     extra=str(input(""))
     if extra=="yes" :
         print("ssd 1tb=10000,games=1000,softwares=900")
         extrapart=str(input())
         if extrapart=="ssd" :
           total_cost=acer_preadatr_helios300+10000
           print("Total:",total_cost)
         elif extrapart=="games" :
           total_cost=acer_preadatr_helios300+1000
           print("Total:",total_cost)
         elif extrapart=="softwares" :
           total_cost=acer_preadatr_helios300+900
           print("Total:",total_cost)
     else:
       print("try for another one")
       print("total cost",total_cost)
 
 
 
def professional(): 
   print("starting from 40k do you want to know  more say yes or no\n")
   decision=str(input(""))
   if decision=="yes" :
     print("great!! let me tell you about the quotation of professional laptops we have")
     print("basic version we have is 1.Acerf =1tb ssd ,ryzen5,cost=40k\n") 
     print("2.acerg=1tb ssd,1tb hdd,,ryzen5,cost=59k\n")
     print("3.acerh=1tb ssd,1tb hdd ,ryzen5,cost=79k\n")
   else:
     print("try for another type")
     
   print("enter the name of laptop")
   lapname=str(input(""))
   if lapname=="acerf" :
     acerf=40000
     print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
     print("do you want to add some extra things say yes or no\n")
     extra=str(input(""))
     if extra=="yes":
         print("ssd 1tb=10000,games=1000,softwares=900")
         extrapart=str(input())
         if extrapart=="ssd" :
           total_cost=acerf+10000
           print("Total:",total_cost)
         elif extrapart=="games" :
           total_cost=acerf+1000
           print("Total:",total_cost)
         elif extrapart=="softwares" :
           total_cost=acerf+900
           print("Total:",total_cost)
     else:
           print("try for another one")
           print("total cost",total_cost)
   
   elif lapname=="acerg" : #comparing string with user input string to enter in the conditional block
       acerg=59000
       print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
       print("do you want to add some extra things say yes or no\n")
       extra=str(input(""))
       if extra=="yes" :
           print("ssd 1tb=10000,games=1000,softwares=900")
           extrapart=str(input())
           if extrapart=="ssd" :
             total_cost=acerg+10000
             print("Total:",total_cost)
           elif extrapart=="games":
             total_cost=acerg+1000
             print("Total:",total_cost)
           elif extrapart=="softwares" :
             total_cost=acerg+900
             print("Total:",total_cost)
       else:
             print("try for another one")
             print("total cost",total_cost)
   
   elif lapname=="acerh" :
     acerh=79000
     print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
     print("do you want to add some extra things say yes or no\n")
     extra=str(input(""))
     if extra=="yes" :
         print("ssd 1tb=10000,games=1000,softwares=900")
         extrapart=str(input())
         if extrapart=="ssd" :
           total_cost=acerh+10000
           print("Total:",total_cost)
         elif extrapart=="games":
           total_cost=acerh+1000
           print("Total:",total_cost)
         elif extrapart=="softwares" :
           total_cost=acerh+900
           print("Total:",total_cost)
     else:
           print("try for another one")
           print("total cost",total_cost)   
 
 
 
 
 
def bussiness():       
  print("starting from 30k do you want to know  more say yes or no\n")
  decision=str(input(""))
  if decision=="yes":
    print("great!! let me tell you about the quotation of bussiness laptops we have")
    print("basic version we have is 1.Acera =1tb ssd ,ryzen4,cost=30k\n") 
    print("2.acerb=1tb ssd,1tb hdd,,ryzen4,cost=39k\n")
    print("3.acer c=1tb ssd,1tb hdd ,ryzen5,cost=69k\n")
  
  else:
    print("try for another type")
    print("enter the name of laptop")
    lapname=str(input(""))
    if lapname=="acera" :
      acera=30000
      print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
      print("do you want to add some extra things say yes or no\n")
      extra=str(input(""))
      if extra=="yes" :
          print("ssd 1tb=10000,games=1000,softwares=900")
          extrapart=str(input())
          if extrapart=="ssd" :
            total_cost=acera+10000
            print("Total:",total_cost)
          elif extrapart=="games" :
            total_cost=acera+1000
            print("Total:",total_cost)
          elif extrapart=="softwares":
            total_cost=acera+900
            print("Total:",total_cost)
      else:
            print("try for another one")
            print("total cost",total_cost)
    
    elif lapname=="acerb" :
        acerb=39000
        print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
        print("do you want to add some extra things say yes or no\n")
        extra=str(input(""))
        if extra=="yes" :
            print("ssd 1tb=10000,games=1000,softwares=900")
            extrapart=str(input())
            if extrapart=="ssd" :
              total_cost=acerb+10000
              print("Total:",total_cost)
            elif extrapart=="games" :
              total_cost=acerb+1000
              print("Total:",total_cost)
            elif extrapart=="softwares" :
              total_cost=acerb+900
              print("Total:",total_cost)
        else:
              print("try for another one")
              print("total cost",total_cost)
    
    elif lapname=="acerc" :
      acerc=690000
      print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
      print("do you want to add some extra things say yes or no\n")
      extra=str(input(""))
      if extra=="yes" :
          print("ssd 1tb=10000,games=1000,softwares=900")
          extrapart=str(input())
          if extrapart=="ssd":
            total_cost=acerc+10000
            print("Total:",total_cost)
          elif extrapart=="games" :
            total_cost=acerc+1000
            print("Total:",total_cost)
          elif extrapart=="softwares" :
            total_cost=acerc+900
            print("Total:",total_cost)
      else:
            print("try for another one")
            print("total cost",total_cost)


 
def gaming1():
   print("starting from 70k do you want to know  more say yes or no\n")
   decision=str(input(""))
   if(decision=="yes"):
     print("great!! let me tell you about the quotation of gaming laptops we have")
     print("basic version we have is 1.dell5 =1tb ssd ,4gb graphics card,ryzen5,cost=70k\n") 
     print("2.dell6=1tb ssd,1tb hdd ,4gb graphics card,ryzen5,cost=1lac\n")
     print("3.dell7=1tb ssd,1tb hdd ,6gb graphics card,ryzen5,cost=2lac\n")
   else:
     print("try for another one")  
   
   print("enter the name of laptop")
   lapname=str(input(""))
   if(lapname=="dell5"):
     dell5=59000
     print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
     print("do you want to add some extra things say yes or no\n")
     extra=str(input(""))
     if (extra=="yes"):
         print("ssd 1tb=10000,games=1000,softwares=900")
         extrapart=str(input())
         if (extrapart=="ssd"):
           total_cost=dell5+10000
           print("Total:",total_cost)
         elif(extrapart=="games"):
           total_cost=dell5+1000
           print("Total:",total_cost)
         elif(extrapart=="softwares"):
           total_cost=dell5+900
           print("Total:",total_cost)
     else:
           print("try for another one")
           print("total cost",total_cost)
   elif(lapname=="dell6"):
       dell6=100000
       print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
       print("do you want to add some extra things say yes or no\n")
       extra=str(input(""))
       if (extra=="yes"):
           print("ssd 1tb=10000,games=1000,softwares=900")
           extrapart=str(input())
           if (extrapart=="ssd"):
             total_cost=dell6+10000
             print("Total:",total_cost)
           elif(extrapart=="games"):
             total_cost=dell6+1000
             print("Total:",total_cost)
           elif(extrapart=="softwares"):
             total_cost=dell6+900
             print("Total:",total_cost)
       else:
             print("try for another one")
             print("total cost",total_cost)
   elif(lapname=="dell7"):
     dell7=200000
     print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
     print("do you want to add some extra things say yes or no\n")
     extra=str(input(""))
     if (extra=="yes"):
         print("ssd 1tb=10000,games=1000,softwares=900")
         extrapart=str(input())
         if (extrapart=="ssd"):
           total_cost=dell7+10000
           print("Total:",total_cost)
         elif(extrapart=="games"):
           total_cost=dell7+1000
           print("Total:",total_cost)
         elif(extrapart=="softwares"):
           total_cost=dell7+900
           print("Total:",total_cost)
     else:
           print("try for another one")
           print("total cost",total_cost)
   
 
 
def professional1(): 
   print("starting from 50k do you want to know  more say yes or no\n")
   decision=str(input(""))
   if(decision=="yes"):
     print("great!! let me tell you about the quotation of professional laptops we have")
     print("basic version we have is 1.dellf =1tb ssd ,ryzen5,cost=50k\n") 
     print("2.dellg=1tb ssd,1tb hdd,,ryzen5,cost=69k\n")
     print("3.dellh=1tb ssd,1tb hdd ,ryzen5,cost=79k\n")
   else:
     print("try for another type")
   print("enter the name of laptop")
   lapname=str(input(""))
   if(lapname=="dellf"):
     dellf=50000
     print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
     print("do you want to add some extra things say yes or no\n")
     extra=str(input(""))
     if (extra=="yes"):
         print("ssd 1tb=10000,games=1000,softwares=900")
         extrapart=str(input())
         if (extrapart=="ssd"):
           total_cost=dellf+10000
           print("Total:",total_cost)
         elif(extrapart=="games"):
           total_cost=dellf+1000
           print("Total:",total_cost)
         elif(extrapart=="softwares"):
           total_cost=dellf+900
           print("Total:",total_cost)
     else:
           print("try for another one")
           print("total cost",total_cost)
   
   elif(lapname=="dellg"):
       dellg=69000
       print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
       print("do you want to add some extra things say yes or no\n")
       extra=str(input(""))
       if (extra=="yes"):
           print("ssd 1tb=10000,games=1000,softwares=900")
           extrapart=str(input())
           if (extrapart=="ssd"):
             total_cost=dellg+10000
             print("Total:",total_cost)
           elif(extrapart=="games"):
             total_cost=dellg+1000
             print("Total:",total_cost)
           elif(extrapart=="softwares"):
             total_cost=dellg+900
             print("Total:",total_cost)
       else:
             print("try for another one")
             print("total cost",total_cost)
   
   elif(lapname=="dellh"):
     dellh=79000
     print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
     print("do you want to add some extra things say yes or no\n")
     extra=str(input(""))
     if (extra=="yes"):
         print("ssd 1tb=10000,games=1000,softwares=900")
         extrapart=str(input())
         if (extrapart=="ssd"):
           total_cost=dellh+10000
           print("Total:",total_cost)
         elif(extrapart=="games"):
           total_cost=dellh+1000
           print("Total:",total_cost)
         elif(extrapart=="softwares"):
           total_cost=dellh+900
           print("Total:",total_cost)
     else:
           print("try for another one")
           print("total cost",total_cost)
 
 
 
 
 
 
def bussiness1():       
  print("starting from 30k do you want to know  more say yes or no\n")
  decision=str(input(""))
  if(decision=="yes"):
    print("great!! let me tell you about the quotation of bussiness laptops we have")
    print("basic version we have is 1.della =1tb ssd ,ryzen4,cost=40k\n") 
    print("2.dellb=1tb ssd,1tb hdd,,ryzen4,cost=39k\n")
    print("3.dellc=1tb ssd,1tb hdd ,ryzen5,cost=69k\n")
  
  else:
    print("try for another type")
  print("enter the name of laptop")
  lapname=str(input(""))
  if(lapname=="della"):
    della=30000
    print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
    print("do you want to add some extra things say yes or no\n")
    extra=str(input(""))
    if (extra=="yes"):
        print("ssd 1tb=10000,games=1000,softwares=900")
        extrapart=str(input())
        if (extrapart=="ssd"):
          total_cost=della+10000
          print("Total:",total_cost)
        elif(extrapart=="games"):
          total_cost=della+1000
          print("Total:",total_cost)
        elif(extrapart=="softwares"):
          total_cost=della+900
          print("Total:",total_cost)
    else:
          print("try for another one")
          print("total cost",total_cost)
  elif(lapname=="dellb"):
      dellb=39000
      print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
      print("do you want to add some extra things say yes or no\n")
      extra=str(input(""))
      if (extra=="yes"):
          print("ssd 1tb=10000,games=1000,softwares=900")
          extrapart=str(input())
          if (extrapart=="ssd"):
            total_cost=dellb+10000
            print("Total:",total_cost)
          elif(extrapart=="games"):
            total_cost=dellb+1000
            print("Total:",total_cost)
          elif(extrapart=="softwares"):
            total_cost=dellb+900
            print("Total:",total_cost)
      else:
            print("try for another one")
            print("total cost",total_cost)
  
  elif(lapname=="dellc"):
    dellc=690000
    print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
    print("do you want to add some extra things say yes or no\n")
    extra=str(input(""))
    if (extra=="yes"):
        print("ssd 1tb=10000,games=1000,softwares=900")
        extrapart=str(input())
        if (extrapart=="ssd"):
          total_cost=dellc+10000
          print("Total:",total_cost)
        elif(extrapart=="games"):
          total_cost=dellc+1000
          print("Total:",total_cost)
        elif(extrapart=="softwares"):
          total_cost=dellc+900
          print("Total:",total_cost)
    else:
          print("try for another one")
          print("total cost",total_cost)  
 
 

 
 
 

 
def gaming2():
   print("starting from 60k do you want to know  more say yes or no\n")
   decision=str(input(""))
   if(decision=="yes"):
     print("great!! let me tell you about the quotation of gaming laptops we have")
     print("basic version we have is 1.lenovo1 =1tb ssd ,4gb graphics card,ryzen5,cost=65k\n") 
     print("2.lenovo2=1tb ssd,1tb hdd ,4gb graphics card,ryzen5,cost=89k\n")
     print("3.lenovo3=1tb ssd,1tb hdd ,6gb graphics card,ryzen5,cost=1lac\n")
   else:
     print("try for another one")  
   print("enter the name of laptop")
   lapname=str(input(""))
   if(lapname=="lenovo1"):
     lenovo1=65000
     print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
     print("do you want to add some extra things say yes or no\n")
     extra=str(input(""))
     if (extra=="yes"):
         print("ssd 1tb=10000,games=1000,softwares=900")
         extrapart=str(input())
         if (extrapart=="ssd"):
           total_cost=lenovo1+10000
           print("Total:",total_cost)
         elif(extrapart=="games"):
           total_cost=lenovo1+1000
           print("Total:",total_cost)
         elif(extrapart=="softwares"):
           total_cost=lenovo1+900
           print("Total:",total_cost)
     else:
           print("try for another one")
           print("total cost",total_cost)
   elif(lapname=="lenovo2"):
       lenovo2=79000
       print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
       print("do you want to add some extra things say yes or no\n")
       extra=str(input(""))
       if (extra=="yes"):
           print("ssd 1tb=10000,games=1000,softwares=900")
           extrapart=str(input())
           if (extrapart=="ssd"):
             total_cost=lenovo2+10000
             print("Total:",total_cost)
           elif(extrapart=="games"):
             total_cost=lenovo2+1000
             print("Total:",total_cost)
           elif(extrapart=="softwares"):
             total_cost=lenovo2+900
             print("Total:",total_cost)
       else:
             print("try for another one")
             print("total cost",total_cost)
   elif(lapname=="lenovo3"):
     lenovo3=100000
     print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
     print("do you want to add some extra things say yes or no\n")
     extra=str(input(""))
     if (extra=="yes"):
         print("ssd 1tb=10000,games=1000,softwares=900")
         extrapart=str(input())
         if (extrapart=="ssd"):
           total_cost=lenovo3+10000
           print("Total:",total_cost)
         elif(extrapart=="games"):
           total_cost=lenovo3+1000
           print("Total:",total_cost)
         elif(extrapart=="softwares"):
           total_cost=lenovo3+900
           print("Total:",total_cost)
     else:
           print("try for another one")
           print("total cost",total_cost)
   
   
 
def professional2(): 
   print("starting from 40k do you want to know  more say yes or no\n")
   decision=str(input(""))
   if(decision=="yes"):
     print("great!! let me tell you about the quotation of professional laptops we have")
     print("basic version we have is 1.lenovof =1tb ssd ,ryzen5,cost=50k\n") 
     print("2.lenovog=1tb ssd,1tb hdd,,ryzen5,cost=59k\n")
     print("3.lenovoh=1tb ssd,1tb hdd ,ryzen5,cost=79k\n")
   else:
     print("try for another type")
   print("enter the name of laptop")
   lapname=str(input(""))
   if(lapname=="lenovof"):
     lenovof=50000
     print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
     print("do you want to add some extra things say yes or no\n")
     extra=str(input(""))
     if (extra=="yes"):
         print("ssd 1tb=10000,games=1000,softwares=900")
         extrapart=str(input())
         if (extrapart=="ssd"):
           total_cost=lenovof+10000
           print("Total:",total_cost)
         elif(extrapart=="games"):
           total_cost=lenovof+1000
           print("Total:",total_cost)
         elif(extrapart=="softwares"):
           total_cost=lenovof+900
           print("Total:",total_cost)
     else:
           print("try for another one")
           print("total cost",total_cost)
   
   elif(lapname=="lenovog"):
       lenovog=59000
       print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
       print("do you want to add some extra things say yes or no\n")
       extra=str(input(""))
       if (extra=="yes"):
           print("ssd 1tb=10000,games=1000,softwares=900")
           extrapart=str(input())
           if (extrapart=="ssd"):
             total_cost=lenovog+10000
             print("Total:",total_cost)
           elif(extrapart=="games"):
             total_cost=lenovog+1000
             print("Total:",total_cost)
           elif(extrapart=="softwares"):
             total_cost=lenovog+900
             print("Total:",total_cost)
       else:
             print("try for another one")
             print("total cost",total_cost)
   
   elif(lapname=="lenovoh"):
     lenovoh=79000
     print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
     print("do you want to add some extra things say yes or no\n")
     extra=str(input(""))
     if (extra=="yes"):
         print("ssd 1tb=10000,games=1000,softwares=900")
         extrapart=str(input())
         if (extrapart=="ssd"):
           total_cost=lenovoh+10000
           print("Total:",total_cost)
         elif(extrapart=="games"):
           total_cost=lenovoh+1000
           print("Total:",total_cost)
         elif(extrapart=="softwares"):
           total_cost=lenovoh+900
           print("Total:",total_cost)
     else:
           print("try for another one")
           print("total cost",total_cost)
     
 
 
 
 
def bussiness2():       
  print("starting from 30k do you want to know  more say yes or no\n")
  decision=str(input(""))
  if(decision=="yes"):
    print("great!! let me tell you about the quotation of bussiness laptops we have")
    print("basic version we have is 1.lenovoa =1tb ssd ,ryzen4,cost=30k\n") 
    print("2.lenovob=1tb ssd,1tb hdd,,ryzen4,cost=39k\n")
    print("3.lenovoc=1tb ssd,1tb hdd ,ryzen5,cost=69k\n")  
  else:
    print("try for another type")
  print("enter the name of laptop")
  lapname=str(input(""))
  if(lapname=="lenovoa"):
    lenovoa=30000
    print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
    print("do you want to add some extra things say yes or no\n")
    extra=str(input(""))
    if (extra=="yes"):
        print("ssd 1tb=10000,games=1000,softwares=900")
        extrapart=str(input())
        if (extrapart=="ssd"):
          total_cost=lenovoa+10000
          print("Total:",total_cost)
        elif(extrapart=="games"):
          total_cost=lenovoa+1000
          print("Total:",total_cost)
        elif(extrapart=="softwares"):
          total_cost=lenovoa+900
          print("Total:",total_cost)
    else:
          print("try for another one")
          print("total cost",total_cost)
  
  elif(lapname=="lenovob"):
      lenovob=39000
      print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
      print("do you want to add some extra things say yes or no\n")
      extra=str(input(""))
      if (extra=="yes"):
          print("ssd 1tb=10000,games=1000,softwares=900")
          extrapart=str(input())
          if (extrapart=="ssd"):
            total_cost=lenovob+10000
            print("Total:",total_cost)
          elif(extrapart=="games"):
            total_cost=lenovob+1000
            print("Total:",total_cost)
          elif(extrapart=="softwares"):
            total_cost=lenovob+900
            print("Total:",total_cost)
      else:
            print("try for another one")
            print("total cost",total_cost)
  
  elif(lapname=="lenovoc"):
    lenovoc=690000
    print("accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free\n")
    print("do you want to add some extra things say yes or no\n")
    extra=str(input(""))
    if (extra=="yes"):
        print("ssd 1tb=10000,games=1000,softwares=900")
        extrapart=str(input())
        if (extrapart=="ssd"):
          total_cost=lenovoc+10000
          print("Total:",total_cost)
        elif(extrapart=="games"):
          total_cost=lenovoc+1000
          print("Total:",total_cost)
        elif(extrapart=="softwares"):
          total_cost=lenovoc+900
          print("Total:",total_cost)
    else:
          print("try for another one")
          print("total cost",total_cost)


companies=["acer","dell","lenovo"] #list defined
print(companies) #printing list here
print("enter the name of laptop company you need\n")
brand=str(input("enter the brand"))
if brand=="acer":
  print("enter your budget")
  budget=int(input(""))
  if budget>60000 :
    gaming()
  elif budget>35000 and budget<40000:
    professional()                       
  elif budget>30000 and budget<35000 :
    bussiness()
 
if(brand=="dell"):
  print("enter your budget")
  budget=int(input(""))
  if(budget>70000):
    gaming1()
  elif(budget>70000 and budget<100000):
    professional1()                       
  elif(budget>100000 and budget<200000):
    bussiness1()

if(brand=="lenovo"):
 print("enter your budget")
 budget=int(input(""))
 if(budget>60000):
   gaming2() #functional call 
 elif(budget>65000 and budget<890000):
   professional2()                       
 elif(budget>890000 and budget<100000):
   bussiness2()
# Out:
# ['acer', 'dell', 'lenovo']
# enter the name of laptop company you need
#
# enter the brandlenovo
# enter your budget
# 70000
# starting from 60k do you want to know  more say yes or no
#
# yes
# great!! let me tell you about the quotation of gaming laptops we have
# basic version we have is 1.lenovo1 =1tb ssd ,4gb graphics card,ryzen5,cost=65k
#
# 2.lenovo2=1tb ssd,1tb hdd ,4gb graphics card,ryzen5,cost=89k
#
# 3.lenovo3=1tb ssd,1tb hdd ,6gb graphics card,ryzen5,cost=1lac
#
# enter the name of laptop
# lenovo3
# accessorries  coming with it is cleaning kit,mouse pad,,mouse thats for free
#
# do you want to add some extra things say yes or no
#
# yes
# ssd 1tb=10000,games=1000,softwares=900
# ssd
# Total: 110000
